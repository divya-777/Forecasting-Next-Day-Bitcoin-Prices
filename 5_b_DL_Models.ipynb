# %% [markdown]
# # Modelleling

# %% [markdown]
# ## Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from keras import *
from keras.callbacks import *
from keras.layers import *
from google.colab import files
from sklearn.preprocessing import MinMaxScaler,RobustScaler,StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.decomposition import PCA
import math
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set_style("darkgrid")
import datetime

# %% [markdown]
# ## Loading Data

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a6262859-55ee-4c42-a29e-da779a836e43" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a6262859-55ee-4c42-a29e-da779a836e43">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data_selected_final_24_4.csv to data_selected_final_24_4.csv

# %%
data_selected_final_24_4 = pd.read_csv('data_selected_final_24_4.csv')

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Sliding Windows & splitting data

# %%
def sliding_intervals(df):
  
  # selecting intervals with window side of 500
  window = 500
  window_interval = []
  train_windows = []
  test_windows = []

  # splitting each window into train and test data sets
  test_window = int(window*0.2)
  train_window = int(window*0.8)
  for i in range(0, len(df), test_window):
    if len(df.iloc[i:i+train_window,:]) >=400:
      window_interval.append(df.iloc[i:i+window,:].reset_index(drop=True)) 
      train_windows.append(df.iloc[i:i+train_window,:].reset_index(drop=True))
      test_windows.append(df.iloc[i+train_window:i+window,:].reset_index(drop=True))
  return window_interval,train_windows, test_windows

# %% [markdown]
# ### Feature Scaling

# %%
# function to scale data with robust and min-max scalers
def scale_data(X_fit,X_tras):
  scale1 = RobustScaler()
  scale2 = MinMaxScaler()
  scale = make_pipeline(scale1,scale2)
  scale.fit(X_fit)
  return scale.transform(X_tras)

# function to scale data with standard scaler
def scale_data1(X_fit,X_tras):
  scale1 = StandardScaler()
  scale = make_pipeline(scale1)
  scale.fit(X_fit)
  return scale.transform(X_tras)

# function to decompose the data into components using PCA
def Principle_component_analysis(X_fit,X_tras,a):
  pca = PCA(n_components=a)  
  X_fit = pca.fit_transform(X_fit)
  X_tras = pca.transform(X_tras)
  return X_fit,X_tras

# %% [markdown]
# ### Metrics

# %%
# Function to calculate Root Mean Square Error
# where y and y_pred are actual and predicted target variables
def RMSE(y,y_pred):
  n =len(y)
  sum = 0
  for i in range(n):
    sum += math.pow((y[i]-y_pred[i]),2)
  MSE = sum/n
  RMSE = np.sqrt(MSE)
  return RMSE

# %%
# Function to calculate  Mean Absolute Error:
def MAE(y,y_pred):
  n =len(y)
  sum = 0
  for i in range(n):
    sum += abs(y[i]-y_pred[i])
  MAE = sum/n
  return MAE

# %%
# Function to calculate Mean Absolute Percentage Error:
def MAPE(y,y_pred):
  n =len(y)
  y_sum = np.sum(y)
  sum = 0
  for i in range(n):
    sum += abs(y[i]-y_pred[i])
  MAPE = (sum/y_sum)
  return MAPE

# %%
def metrics_final(data,y,y_pred):
  print('MAE_'+str(data)+':',MAE(y,y_pred))
  print('MAPE_'+str(data)+':',MAPE(y,y_pred))
  print('RMSE_'+str(data)+':',RMSE(y,y_pred))

# %% [markdown]
# ### Outliers

# %%
# Function to remove outliers using isolation forest 
def outliers(df,a):
  outlier=IsolationForest(contamination=a)
  BTC_price = df['next_day_BTC_price'].values
  BTC_price=np.reshape(BTC_price,(-1,1))
  outlier.fit(BTC_price)
  outs=outlier.predict(BTC_price)
  df['outlier']=outs
  df_new=df.query('outlier != -1')
  df_new.drop(columns=['outlier'],inplace=True)
  return df_new

# %% [markdown]
# ## LSTM

# %%
data_selected_final = data_selected_final_24_4.copy()

# %%
window_interval,train_windows, test_windows = sliding_intervals(data_selected_final)

# %%
# Function to schedule learning rate for each epoch
def Learning_Rate_scheduler(epoch,lr):
    if (epoch+1) == 1:
        lr = 0.001
    if (epoch+1)%5==0:
        return lr*0.98
    else:
        return lr

# %%
# LSTM Algorithm
model = Sequential()
model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(100, return_sequences=True, activation='relu'),input_shape=(1,12)))
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(100, return_sequences=True, activation='relu')))
model.add(tf.keras.layers.Dropout(0.25))
model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(100, return_sequences=True, activation='relu')))
model.add(tf.keras.layers.Dropout(0.25))
model.add(tf.keras.layers.Dense(1))

adam=tf.keras.optimizers.Adam(learning_rate=0.001,amsgrad=True)
model.compile(loss="log_cosh", optimizer=adam, metrics=['mae'])
earlyStopping = EarlyStopping(monitor='val_loss', patience=50, verbose=1, mode='auto')
lr_schedule=LearningRateScheduler(Learning_Rate_scheduler, verbose=True)
reduce_lr=ReduceLROnPlateau(monitor='mae', factor=0.98,patience=3,verbose=1,mode='min')

# Lists to store metric values
train_metric_MAE = []
train_metric_RMSE = []
train_metric_MAPE = []
test_metric_MAE = []
test_metric_RMSE = []
test_metric_MAPE = []
start_date = []
end_date = []
Date = []
y_actual = []
y_pred = []
history = []

for i in range(len(train_windows)):
  #train_window_II = outliers(train_windows[i],0.3)
  train_window_II = train_windows[i]
  test_window_II = test_windows[i]
  x_train_windows = train_window_II.iloc[:,1:-1]
  y_train_windows = train_window_II.iloc[:,-1:]
  x_test_windows = test_window_II.iloc[:,1:-1]
  y_test_windows = test_window_II.iloc[:,-1:]
  Date.extend(np.ravel(test_window_II['Date']))
  y_actual.extend(np.ravel(y_test_windows))

  x_train_windows_scaled = scale_data(x_train_windows,x_train_windows)
  x_test_windows_scaled = scale_data(x_train_windows,x_test_windows)

  x_train_windows_scaled=np.reshape(x_train_windows_scaled,
                                         (x_train_windows_scaled.shape[0],1,x_train_windows_scaled.shape[1]))
  y_train_windows=np.reshape(y_train_windows.values,(y_train_windows.shape[0],1,1))
  x_test_windows_scaled=np.reshape(x_test_windows_scaled,
                                        (x_test_windows_scaled.shape[0],1,x_test_windows_scaled.shape[1]))
  y_test_windows=np.reshape(y_test_windows.values,(y_test_windows.shape[0],1,1))

  history.append(model.fit(x_train_windows_scaled,y_train_windows, epochs=500, batch_size=32, 
                    validation_data=(x_test_windows_scaled,y_test_windows), callbacks=[earlyStopping,lr_schedule,reduce_lr]))

  y_train_pred_LSTM = model.predict(x_train_windows_scaled)
  y_test_pred_LSTM = model.predict(x_test_windows_scaled)
  y_pred.extend(np.ravel(y_test_pred_LSTM))
  
  train_metric_MAE.append(MAE(np.ravel(y_train_windows),np.ravel(y_train_pred_LSTM)))
  print(str(i+1)*75)
  print("train_metric_MAE:",train_metric_MAE)
  train_metric_RMSE.append(RMSE(np.ravel(y_train_windows),np.ravel(y_train_pred_LSTM)))
  print(str(i+1)*75)
  train_metric_MAPE.append(MAPE(np.ravel(y_train_windows),np.ravel(y_train_pred_LSTM)))

LearningRateScheduler setting learning rate to 0.0003568862739484757.
# Epoch 104/500
# 12/13 [==========================>...] - ETA: 0s - loss: 508.8213 - mae: 509.5135
# Epoch 104: ReduceLROnPlateau reducing learning rate to 0.0003497485484695062.
# 13/13 [==============================] - 0s 28ms/step - loss: 509.3809 - mae: 510.0732 - val_loss: 225.1494 - val_mae: 225.8396 - lr: 3.5689e-04
#
# Epoch 105: LearningRateScheduler setting learning rate to 0.0003427535883383825.
# Epoch 105/500
# 13/13 [==============================] - 0s 31ms/step - loss: 490.1747 - mae: 490.8675 - val_loss: 224.8431 - val_mae: 225.5362 - lr: 3.4275e-04
#
# Epoch 106: LearningRateScheduler setting learning rate to 0.0003427535993978381.
# Epoch 106/500
# 13/13 [==============================] - 0s 28ms/step - loss: 538.9961 - mae: 539.6892 - val_loss: 230.3159 - val_mae: 231.0082 - lr: 3.4275e-04
#
# Epoch 107: LearningRateScheduler setting learning rate to 0.0003427535993978381.
# Epoch 107/500
# 11/13 [========================>.....] - ETA: 0s - loss: 476.0895 - mae: 476.7826
# Epoch 107: ReduceLROnPlateau reducing learning rate to 0.00033589852740988134.
# 13/13 [==============================] - 0s 29ms/step - loss: 479.0952 - mae: 479.7882 - val_loss: 238.7664 - val_mae: 239.4552 - lr: 3.4275e-04
#
# Epoch 108: LearningRateScheduler setting learning rate to 0.00033589854137971997.
# Epoch 108/500
# 13/13 [==============================] - 0s 32ms/step - loss: 496.5895 - mae: 497.2809 - val_loss: 234.7713 - val_mae: 235.4613 - lr: 3.3590e-04
#
# Epoch 109: LearningRateScheduler setting learning rate to 0.00033589854137971997.
# Epoch 109/500
# 13/13 [==============================] - 0s 38ms/step - loss: 509.6296 - mae: 510.3220 - val_loss: 245.9937 - val_mae: 246.6867 - lr: 3.3590e-04
#
# Epoch 110: LearningRateScheduler setting learning rate to 0.00032918057055212555.
# Epoch 110/500
# 13/13 [==============================] - ETA: 0s - loss: 482.1935 - mae: 482.8866
# Epoch 110: ReduceLROnPlateau reducing learning rate to 0.000322596951154992.
# 13/13 [==============================] - 1s 41ms/step - loss: 482.1935 - mae: 482.8866 - val_loss: 235.3833 - val_mae: 236.0755 - lr: 3.2918e-04
#
# Epoch 111: LearningRateScheduler setting learning rate to 0.00032259695581160486.
# Epoch 111/500
# 13/13 [==============================] - 0s 30ms/step - loss: 491.4838 - mae: 492.1769 - val_loss: 226.3897 - val_mae: 227.0829 - lr: 3.2260e-04
#
# Epoch 112: LearningRateScheduler setting learning rate to 0.00032259695581160486.
# Epoch 112/500
# 13/13 [==============================] - 0s 34ms/step - loss: 486.3102 - mae: 487.0011 - val_loss: 225.3048 - val_mae: 225.9971 - lr: 3.2260e-04
#
# Epoch 113: LearningRateScheduler setting learning rate to 0.00032259695581160486.
# Epoch 113/500
# 12/13 [==========================>...] - ETA: 0s - loss: 477.9625 - mae: 478.6555
# Epoch 113: ReduceLROnPlateau reducing learning rate to 0.0003161450166953728.
# 13/13 [==============================] - 0s 29ms/step - loss: 487.2192 - mae: 487.9123 - val_loss: 244.9678 - val_mae: 245.6609 - lr: 3.2260e-04
#
# Epoch 114: LearningRateScheduler setting learning rate to 0.00031614501494914293.
# Epoch 114/500
# 13/13 [==============================] - 0s 30ms/step - loss: 493.8924 - mae: 494.5852 - val_loss: 246.1117 - val_mae: 246.8047 - lr: 3.1615e-04
#
# Epoch 115: LearningRateScheduler setting learning rate to 0.00030982211465016004.
# Epoch 115/500
# 13/13 [==============================] - 0s 30ms/step - loss: 488.3367 - mae: 489.0289 - val_loss: 226.2829 - val_mae: 226.9709 - lr: 3.0982e-04
#
# Epoch 116: LearningRateScheduler setting learning rate to 0.00030982212047092617.
# Epoch 116/500
# 13/13 [==============================] - ETA: 0s - loss: 472.1388 - mae: 472.8319
# Epoch 116: ReduceLROnPlateau reducing learning rate to 0.0003036256780615076.
# 13/13 [==============================] - 0s 36ms/step - loss: 472.1388 - mae: 472.8319 - val_loss: 229.4820 - val_mae: 230.1748 - lr: 3.0982e-04
#
# Epoch 117: LearningRateScheduler setting learning rate to 0.0003036256821360439.
# Epoch 117/500
# 13/13 [==============================] - 0s 36ms/step - loss: 477.2168 - mae: 477.9083 - val_loss: 224.9103 - val_mae: 225.6017 - lr: 3.0363e-04
#
# Epoch 118: LearningRateScheduler setting learning rate to 0.0003036256821360439.
# Epoch 118/500
# 13/13 [==============================] - 0s 30ms/step - loss: 463.1421 - mae: 463.8353 - val_loss: 262.4628 - val_mae: 263.1554 - lr: 3.0363e-04
#
# Epoch 119: LearningRateScheduler setting learning rate to 0.0003036256821360439.
# Epoch 119/500
# 12/13 [==========================>...] - ETA: 0s - loss: 481.0151 - mae: 481.7067
# Epoch 119: ReduceLROnPlateau reducing learning rate to 0.000297553168493323.
# 13/13 [==============================] - 0s 29ms/step - loss: 481.2817 - mae: 481.9734 - val_loss: 226.7635 - val_mae: 227.4566 - lr: 3.0363e-04
#
# Epoch 120: LearningRateScheduler setting learning rate to 0.0002916021045530215.
# Epoch 120/500
# 13/13 [==============================] - 0s 33ms/step - loss: 494.9901 - mae: 495.6815 - val_loss: 232.7374 - val_mae: 233.4284 - lr: 2.9160e-04
#
# Epoch 121: LearningRateScheduler setting learning rate to 0.0002916021039709449.
# Epoch 121/500
# 13/13 [==============================] - 0s 31ms/step - loss: 522.6080 - mae: 523.2993 - val_loss: 244.9659 - val_mae: 245.6591 - lr: 2.9160e-04
#
# Epoch 122: LearningRateScheduler setting learning rate to 0.0002916021039709449.
# Epoch 122/500
# 12/13 [==========================>...] - ETA: 0s - loss: 511.9570 - mae: 512.6501
# Epoch 122: ReduceLROnPlateau reducing learning rate to 0.000285770061891526.
# 13/13 [==============================] - 0s 33ms/step - loss: 509.9131 - mae: 510.6063 - val_loss: 226.5220 - val_mae: 227.2151 - lr: 2.9160e-04
#
# Epoch 123: LearningRateScheduler setting learning rate to 0.0002857700746972114.
# Epoch 123/500
# 13/13 [==============================] - 0s 29ms/step - loss: 464.2366 - mae: 464.9298 - val_loss: 228.7197 - val_mae: 229.4128 - lr: 2.8577e-04
#
# Epoch 124: LearningRateScheduler setting learning rate to 0.0002857700746972114.
# Epoch 124/500
# 13/13 [==============================] - 0s 29ms/step - loss: 484.0618 - mae: 484.7527 - val_loss: 250.9226 - val_mae: 251.6157 - lr: 2.8577e-04
#
# Epoch 125: LearningRateScheduler setting learning rate to 0.0002800546732032672.
# Epoch 125/500
# 13/13 [==============================] - ETA: 0s - loss: 523.0774 - mae: 523.7703
# Epoch 125: ReduceLROnPlateau reducing learning rate to 0.00027445357118267567.
# 13/13 [==============================] - 0s 33ms/step - loss: 523.0774 - mae: 523.7703 - val_loss: 224.5487 - val_mae: 225.2401 - lr: 2.8005e-04
#
# Epoch 126: LearningRateScheduler setting learning rate to 0.0002744535740930587.
# Epoch 126/500
# 13/13 [==============================] - 0s 30ms/step - loss: 507.6102 - mae: 508.3004 - val_loss: 235.5199 - val_mae: 236.2131 - lr: 2.7445e-04
#
# Epoch 127: LearningRateScheduler setting learning rate to 0.0002744535740930587.
# Epoch 127/500
# 13/13 [==============================] - 0s 31ms/step - loss: 482.3643 - mae: 483.0573 - val_loss: 225.2123 - val_mae: 225.9054 - lr: 2.7445e-04
#
# Epoch 128: LearningRateScheduler setting learning rate to 0.0002744535740930587.
# Epoch 128/500
# 12/13 [==========================>...] - ETA: 0s - loss: 492.4351 - mae: 493.1272
# Epoch 128: ReduceLROnPlateau reducing learning rate to 0.0002689645026111975.
# 13/13 [==============================] - 0s 30ms/step - loss: 490.2262 - mae: 490.9183 - val_loss: 233.6279 - val_mae: 234.3210 - lr: 2.7445e-04
#
# Epoch 129: LearningRateScheduler setting learning rate to 0.00026896450435742736.
# Epoch 129/500
# 13/13 [==============================] - 0s 30ms/step - loss: 478.6312 - mae: 479.3243 - val_loss: 224.7429 - val_mae: 225.4356 - lr: 2.6896e-04
#
# Epoch 130: LearningRateScheduler setting learning rate to 0.0002635852142702788.
# Epoch 130/500
# 13/13 [==============================] - 0s 31ms/step - loss: 457.8642 - mae: 458.5574 - val_loss: 224.8124 - val_mae: 225.5055 - lr: 2.6359e-04
#
# Epoch 131: LearningRateScheduler setting learning rate to 0.0002635852142702788.
# Epoch 131/500
# 12/13 [==========================>...] - ETA: 0s - loss: 466.5902 - mae: 467.2830
# Epoch 131: ReduceLROnPlateau reducing learning rate to 0.0002583135099848732.
# 13/13 [==============================] - 0s 31ms/step - loss: 466.8056 - mae: 467.4983 - val_loss: 243.6275 - val_mae: 244.3118 - lr: 2.6359e-04
#
# Epoch 132: LearningRateScheduler setting learning rate to 0.0002583135210443288.
# Epoch 132/500
# 13/13 [==============================] - 0s 31ms/step - loss: 470.3767 - mae: 471.0697 - val_loss: 242.4646 - val_mae: 243.1565 - lr: 2.5831e-04
#
# Epoch 133: LearningRateScheduler setting learning rate to 0.0002583135210443288.
# Epoch 133/500
# 13/13 [==============================] - 0s 39ms/step - loss: 520.7222 - mae: 521.4152 - val_loss: 269.7517 - val_mae: 270.4446 - lr: 2.5831e-04
#
# Epoch 134: LearningRateScheduler setting learning rate to 0.0002583135210443288.
# Epoch 134/500
# 13/13 [==============================] - ETA: 0s - loss: 469.0092 - mae: 469.7017
# Epoch 134: ReduceLROnPlateau reducing learning rate to 0.00025314725062344225.
# 13/13 [==============================] - 0s 35ms/step - loss: 469.0092 - mae: 469.7017 - val_loss: 226.8068 - val_mae: 227.4996 - lr: 2.5831e-04
#
# ...
# Epoch 80/500
# 12/13 [==========================>...] - ETA: 0s - loss: 3328.6777 - mae: 3329.3708
# Epoch 80: ReduceLROnPlateau reducing learning rate to 0.0005134054878726601.
# 13/13 [==============================] - 0s 27ms/step - loss: 3345.3918 - mae: 3346.0850 - val_loss: 1117.4963 - val_mae: 1118.1896 - lr: 5.2388e-04
#
# Epoch 81: LearningRateScheduler setting learning rate to 0
LearningRateScheduler setting learning rate to 0.00039482026477344334.
# Epoch 106/500
# 13/13 [==============================] - 0s 27ms/step - loss: 3279.6086 - mae: 3280.3025 - val_loss: 1172.5714 - val_mae: 1173.2646 - lr: 3.9482e-04
#
# Epoch 107: LearningRateScheduler setting learning rate to 0.00039482026477344334.
# Epoch 107/500
# 11/13 [========================>.....] - ETA: 0s - loss: 3244.1279 - mae: 3244.8213
# Epoch 107: ReduceLROnPlateau reducing learning rate to 0.0003869238594779745.
# 13/13 [==============================] - 0s 30ms/step - loss: 3292.0657 - mae: 3292.7590 - val_loss: 1124.2296 - val_mae: 1124.9229 - lr: 3.9482e-04
#
# Epoch 108: LearningRateScheduler setting learning rate to 0.00038692387170158327.
# Epoch 108/500
# 13/13 [==============================] - 0s 30ms/step - loss: 3068.0566 - mae: 3068.7500 - val_loss: 1120.4375 - val_mae: 1121.1306 - lr: 3.8692e-04
#
# Epoch 109: LearningRateScheduler setting learning rate to 0.00038692387170158327.
# Epoch 109/500
# 13/13 [==============================] - 0s 34ms/step - loss: 3194.0591 - mae: 3194.7524 - val_loss: 1119.9265 - val_mae: 1120.6196 - lr: 3.8692e-04
#
# Epoch 110: LearningRateScheduler setting learning rate to 0.0003791853942675516.
# Epoch 110/500
# 12/13 [==========================>...] - ETA: 0s - loss: 3377.6270 - mae: 3378.3203
# Epoch 110: ReduceLROnPlateau reducing learning rate to 0.0003716016880935058.
# 13/13 [==============================] - 0s 29ms/step - loss: 3371.6240 - mae: 3372.3174 - val_loss: 1123.2478 - val_mae: 1123.9410 - lr: 3.7919e-04
#
# Epoch 111: LearningRateScheduler setting learning rate to 0.0003716016944963485.
# Epoch 111/500
# 13/13 [==============================] - 0s 28ms/step - loss: 3108.0576 - mae: 3108.7512 - val_loss: 1118.4629 - val_mae: 1119.1560 - lr: 3.7160e-04
#
# Epoch 112: LearningRateScheduler setting learning rate to 0.0003716016944963485.
# Epoch 112/500
# 13/13 [==============================] - 0s 30ms/step - loss: 3160.4241 - mae: 3161.1174 - val_loss: 1146.2592 - val_mae: 1146.9521 - lr: 3.7160e-04
#
# Epoch 113: LearningRateScheduler setting learning rate to 0.0003716016944963485.
# Epoch 113/500
# 13/13 [==============================] - ETA: 0s - loss: 3311.7385 - mae: 3312.4319
# Epoch 113: ReduceLROnPlateau reducing learning rate to 0.0003641696606064215.
# 13/13 [==============================] - 0s 34ms/step - loss: 3311.7385 - mae: 3312.4319 - val_loss: 1119.4033 - val_mae: 1120.0964 - lr: 3.7160e-04
#
# Epoch 114: LearningRateScheduler setting learning rate to 0.0003641696530394256.
# Epoch 114/500
# 13/13 [==============================] - 0s 36ms/step - loss: 3302.7881 - mae: 3303.4814 - val_loss: 1124.4694 - val_mae: 1125.1624 - lr: 3.6417e-04
#
# Epoch 115: LearningRateScheduler setting learning rate to 0.0003568862599786371.
# Epoch 115/500
# 13/13 [==============================] - 0s 35ms/step - loss: 3127.1760 - mae: 3127.8694 - val_loss: 1118.8756 - val_mae: 1119.5686 - lr: 3.5689e-04
#
# Epoch 116: LearningRateScheduler setting learning rate to 0.0003568862739484757.
# Epoch 116/500
# 13/13 [==============================] - ETA: 0s - loss: 3144.0845 - mae: 3144.7776
# Epoch 116: ReduceLROnPlateau reducing learning rate to 0.0003497485484695062.
# 13/13 [==============================] - 0s 35ms/step - loss: 3144.0845 - mae: 3144.7776 - val_loss: 1123.9060 - val_mae: 1124.5992 - lr: 3.5689e-04
#
# Epoch 117: LearningRateScheduler setting learning rate to 0.0003497485595289618.
# Epoch 117/500
# 13/13 [==============================] - 0s 32ms/step - loss: 3271.5640 - mae: 3272.2576 - val_loss: 1119.7366 - val_mae: 1120.4297 - lr: 3.4975e-04
#
# Epoch 118: LearningRateScheduler setting learning rate to 0.0003497485595289618.
# Epoch 118/500
# 13/13 [==============================] - 0s 28ms/step - loss: 3241.1821 - mae: 3241.8757 - val_loss: 1169.1729 - val_mae: 1169.8660 - lr: 3.4975e-04
#
# Epoch 119: LearningRateScheduler setting learning rate to 0.0003497485595289618.
# Epoch 119/500
# 12/13 [==========================>...] - ETA: 0s - loss: 3499.1497 - mae: 3499.8420
# Epoch 119: ReduceLROnPlateau reducing learning rate to 0.0003427535883383825.
# 13/13 [==============================] - 0s 30ms/step - loss: 3469.6924 - mae: 3470.3850 - val_loss: 1159.7245 - val_mae: 1160.4176 - lr: 3.4975e-04
#
# Epoch 120: LearningRateScheduler setting learning rate to 0.00033589852740988134.
# Epoch 120/500
# 13/13 [==============================] - 0s 30ms/step - loss: 3384.6826 - mae: 3385.3752 - val_loss: 1125.2922 - val_mae: 1125.9854 - lr: 3.3590e-04
#
# Epoch 121: LearningRateScheduler setting learning rate to 0.00033589854137971997.
# Epoch 121/500
# 13/13 [==============================] - 0s 30ms/step - loss: 3159.3557 - mae: 3160.0488 - val_loss: 1175.6940 - val_mae: 1176.3871 - lr: 3.3590e-04
#
# Epoch 122: LearningRateScheduler setting learning rate to 0.00033589854137971997.
# Epoch 122/500
# 13/13 [==============================] - ETA: 0s - loss: 3032.4893 - mae: 3033.1826
# Epoch 122: ReduceLROnPlateau reducing learning rate to 0.00032918057055212555.
# 13/13 [==============================] - 0s 30ms/step - loss: 3032.4893 - mae: 3033.1826 - val_loss: 1124.1843 - val_mae: 1124.8774 - lr: 3.3590e-04
#
# Epoch 123: LearningRateScheduler setting learning rate to 0.00032918056240305305.
# Epoch 123/500
# 13/13 [==============================] - 0s 30ms/step - loss: 3390.6184 - mae: 3391.3118 - val_loss: 1119.2603 - val_mae: 1119.9534 - lr: 3.2918e-04
#
# Epoch 124: LearningRateScheduler setting learning rate to 0.00032918056240305305.
# Epoch 124/500
# 13/13 [==============================] - 0s 31ms/step - loss: 3245.6421 - mae: 3246.3352 - val_loss: 1144.0670 - val_mae: 1144.7603 - lr: 3.2918e-04
#
# Epoch 125: LearningRateScheduler setting learning rate to 0.000322596951154992.
# Epoch 125/500
# 13/13 [==============================] - ETA: 0s - loss: 3351.7209 - mae: 3352.4148
# Epoch 125: ReduceLROnPlateau reducing learning rate to 0.0003161450166953728.
# 13/13 [==============================] - 0s 28ms/step - loss: 3351.7209 - mae: 3352.4148 - val_loss: 1122.0201 - val_mae: 1122.7134 - lr: 3.2260e-04
#
# Epoch 126: LearningRateScheduler setting learning rate to 0.00031614501494914293.
# Epoch 126/500
# 13/13 [==============================] - 0s 27ms/step - loss: 3129.0225 - mae: 3129.7153 - val_loss: 1134.5936 - val_mae: 1135.2869 - lr: 3.1615e-04
#
# Epoch 127: LearningRateScheduler setting learning rate to 0.00031614501494914293.
# Epoch 127/500
# 13/13 [==============================] - 0s 33ms/step - loss: 3290.7151 - mae: 3291.4084 - val_loss: 1123.8502 - val_mae: 1124.5436 - lr: 3.1615e-04
#
# Epoch 128: LearningRateScheduler setting learning rate to 0.00031614501494914293.
# Epoch 128/500
# 13/13 [==============================] - ETA: 0s - loss: 3232.5110 - mae: 3233.2041
# Epoch 128: ReduceLROnPlateau reducing learning rate to 0.00030982211465016004.
# 13/13 [==============================] - 0s 35ms/step - loss: 3232.5110 - mae: 3233.2041 - val_loss: 1123.2051 - val_mae: 1123.8982 - lr: 3.1615e-04
#
# Epoch 129: LearningRateScheduler setting learning rate to 0.00030982212047092617.
# Epoch 129/500
# 13/13 [==============================] - 0s 35ms/step - loss: 3214.7512 - mae: 3215.4443 - val_loss: 1136.5085 - val_mae: 1137.2017 - lr: 3.0982e-04
#
# Epoch 130: LearningRateScheduler setting learning rate to 0.0003036256780615076.
# Epoch 130/500
# 13/13 [==============================] - 0s 30ms/step - loss: 3124.4500 - mae: 3125.1436 - val_loss: 1129.5620 - val_mae: 1130.2552 - lr: 3.0363e-04
# Epoch 130: early stopping
# 232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323
# train_metric_MAE: [8.397233512878417, 7.8099226760864235, 12.947222969055172, 14.137462356567376, 14.22518484497072, 32.64822848510746, 58.60512741088872, 200.1154995117188, 307.8822286987307, 345.06466772460936, 338.7347130126954, 250.38859838867177, 157.37104736328132, 182.1358270263672, 204.70054968261738, 227.63108605957038, 268.19048242187495, 218.5366909179686, 346.27462158203116, 744.8065612792972, 1095.9250576171878, 1376.7070747070309, 1659.5743291015624]
# 232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323232323

# %%
LSTM_metrics= pd.DataFrame({'start_date':start_date,'end_date':end_date,'mae_train':train_metric_MAE,
                              'rmse_train':train_metric_RMSE,
                              'mape_train':train_metric_MAPE,
                              'mae_test':test_metric_MAE,
                              'rmse_test':test_metric_RMSE,
                              'mape_test':test_metric_MAPE
                              })

# %%
LSTM_metrics.iloc[:,2:].tail(5)
# Out:
#       mae_train   rmse_train  mape_train     mae_test    rmse_test  mape_test
# 18   304.659284   508.568171    0.026694  5639.785445  6579.822337   0.115538
# 19   773.569371  1317.194178    0.035931  2940.695938  3416.077430   0.072700
# 20  1003.680542  1531.291469    0.033922  1442.838891  1837.610311   0.028730
# 21  1306.633639  1762.801620    0.033069  1464.127906  1935.833334   0.030165
# 22  1699.555510  2157.382820    0.036157  1150.795312  1454.523073   0.028106

# %%
pd.DataFrame(LSTM_metrics.iloc[:,2:].mean())
# Out:
#                      0
# mae_train   350.991714
# rmse_train  527.412465
# mape_train    0.033281
# mae_test    754.766380
# rmse_test   989.877186
# mape_test     0.054585

# %%
df_predictions = pd.DataFrame({'Date':Date,'y_actual':y_actual,'y_pred':y_pred})
df_predictions.index = df_predictions['Date']
df_predictions.drop(['Date'],axis=1,inplace=True)
df_predictions.index = pd.to_datetime(df_predictions.index)

# %%
# plotting model performance on seen and unseen data
plt.figure(figsize=(25,6))
plt.plot(df_predictions['y_actual'],  label = "actual",marker='d',markersize=5)
plt.plot(df_predictions['y_pred'],  label = "predicted",marker='d',markersize=2)
plt.title('Plot actual vs predictions over sliding windows')
#plt.xlim(1600,)
plt.legend()
plt.show()
